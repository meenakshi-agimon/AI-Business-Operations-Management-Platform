# %%
import pandas as pd

# -----------------------------
# 1. Load Dataset
# -----------------------------

DATA_PATH = "C:/Users/nived/New folder (2)/AI-Business-Operations-Management-Platform/datasets/cleaned/Business_Operation_ml_ready.csv"

df = pd.read_csv(DATA_PATH)

# -----------------------------
# 2. Basic Dataset Information
# -----------------------------

print("Dataset Shape:")
print(df.shape)

print("\nColumn Names:")
for column in df.columns:
    print(column)

print("\nFirst 5 Rows:")
print(df.head())

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape:
# (50000, 67)
#
# Column Names:
# employee_id
# experience_years
# workload_percentage
# active_tasks
# performance_score
# estimated_hours
# hours_logged
# progress_percentage
# allocation_score
# recommended_employee
# skill_match
# skill_computer_vision
# skill_data_analysis
# skill_deep_learning
# skill_django
# skill_excel
# skill_finance
# skill_machine_learning
# skill_nlp
# skill_project_management
# skill_python
# skill_react
# skill_sql
# department_Data Science
# department_Engineering
# department_Finance
# department_HR
# department_IT
# department_Marketing
# department_Operations
# department_Sales
# job_role_Analyst
# job_role_Business Analyst
# job_role_Data Scientist
# job_role_Developer
# job_role_Finance Analyst
# job_role_HR Executive
# job_role_Project Manager
# job_role_Senior Developer
# job_role_Team Lead
# availability_status_Available
# availability_status_Busy
# availability_status_On Leave
# availability_status_Unknown
# task_priority_Critical
# task_priority_High
# task_priority_Low
# task_priority_Medium
# task_priority_Unknown
# task_status_Blocked
# task_status_Completed
# task_status_In Progress
# task_status_Not Started
# task_status_Unknown
# required_skill_Computer Vision
# required_skill_Data Analysis
# required_skill_Deep Learning
# required_skill_Django
# required_skill_Excel
# required_skill_Finance
# required_skill_Machine Learning
# required_skill_NLP
# required_skill_Project Management
# required_skill_Python
# required_skill_React
# required_skill_SQL
# required_skill_Unknown
#
# First 5 Rows:
#   employee_id  experience_years  workload_percentage  active_tasks  \
# 0     EMP2373               4.1                 27.0             2
# 1     EMP4021               6.1                100.0             8
# 2     EMP2457               2.1                 67.9             2
# 3     EMP2344               4.5                 47.5             3
# 4      EMP205              13.6                 49.3             2
#
#    performance_score  estimated_hours  hours_logged  progress_percentage  \
# 0               71.9             36.5          25.1                 76.8
# 1               75.0             44.4          21.9                 56.9
# 2               62.2             32.0          21.2                 56.6
# 3               72.7             43.1          40.4                 96.7
# 4               77.0             33.5          29.4                 92.8
#
#    allocation_score  recommended_employee  ...  required_skill_Django  \
# 0              16.5                     1  ...                  False
# 1              43.8                     1  ...                  False
# 2              41.9                     1  ...                  False
# 3              22.5                     0  ...                  False
# 4              49.2                     1  ...                  False
#
#    required_skill_Excel  required_skill_Finance  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                    True
#
#    required_skill_Machine Learning  required_skill_NLP  \
# 0                            False               False
# 1                            False                True
# 2                            False               False
# 3                             True               False
# 4                            False               False
#
#    required_skill_Project Management  required_skill_Python  \
# 0                              False                  False
# 1                              False                  False
# 2                               True                  False
# 3                              False                  False
# 4                              False                  False
#
#    required_skill_React  required_skill_SQL  required_skill_Unknown
# 0                 False               False                   False
# 1                 False               False                   False
# 2                 False               False                   False
# 3                 False               False                   False
# 4                 False               False                   False
#
# [5 rows x 67 columns]
#
# Data Types:
# employee_id                           object
# experience_years                     float64
# workload_percentage                  float64
# active_tasks                           int64
# performance_score                    float64
#                                       ...
# required_skill_Project Management       bool
# required_skill_Python                   bool
# required_skill_React                    bool
# required_skill_SQL                      bool
# required_skill_Unknown                  bool
# Length: 67, dtype: object
#
# Missing Values:
# employee_id                          0
# experience_years                     0
# workload_percentage                  0
# active_tasks                         0
# performance_score                    0
#                                     ..
# required_skill_Project Management    0
# required_skill_Python                0
# required_skill_React                 0
# required_skill_SQL                   0
# required_skill_Unknown               0
# Length: 67, dtype: int64

# %%
project_features = [
    "employee_id",
    "workload_percentage",
    "active_tasks",
    "estimated_hours",
    "hours_logged",
    "progress_percentage",
    "task_priority_Critical",
    "task_priority_High",
    "task_priority_Low",
    "task_priority_Medium",
    "task_priority_Unknown",
    "task_status_Blocked",
    "task_status_Completed",
    "task_status_In Progress",
    "task_status_Not Started",
    "task_status_Unknown"
]

project_df = df[project_features].copy()

print("Project Management Data Shape:")
print(project_df.shape)

print("\nProject Management Columns:")
print(project_df.columns.tolist())

print("\nFirst 5 Rows:")
display(project_df.head())
# Out:
# Project Management Data Shape:
# (50000, 16)
#
# Project Management Columns:
# ['employee_id', 'workload_percentage', 'active_tasks', 'estimated_hours', 'hours_logged', 'progress_percentage', 'task_priority_Critical', 'task_priority_High', 'task_priority_Low', 'task_priority_Medium', 'task_priority_Unknown', 'task_status_Blocked', 'task_status_Completed', 'task_status_In Progress', 'task_status_Not Started', 'task_status_Unknown']
#
# First 5 Rows:
#   employee_id  workload_percentage  active_tasks  estimated_hours  \
# 0     EMP2373                 27.0             2             36.5
# 1     EMP4021                100.0             8             44.4
# 2     EMP2457                 67.9             2             32.0
# 3     EMP2344                 47.5             3             43.1
# 4      EMP205                 49.3             2             33.5
#
#    hours_logged  progress_percentage  task_priority_Critical  \
# 0          25.1                 76.8                   False
# 1          21.9                 56.9                   False
# 2          21.2                 56.6                   False
# 3          40.4                 96.7                   False
# 4          29.4                 92.8                   False
#
#    task_priority_High  task_priority_Low  task_priority_Medium  \
# 0                True              False                 False
# 1               False              False                  True
# 2               False              False                  True
# 3               False              False                  True
# 4               False              False                  True
#
#    task_priority_Unknown  task_status_Blocked  task_status_Completed  \
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                   True
# 4                  False                 True                  False
#
#    task_status_In Progress  task_status_Not Started  task_status_Unknown
# 0                     True                    False                False
# 1                     True                    False                False
# 2                     True                    False                False
# 3                    False                    False                False
# 4                    False                    False                False

# %%
print("\n--- Numerical Statistics ---")

print(
    project_df[
        [
            "workload_percentage",
            "active_tasks",
            "estimated_hours",
            "hours_logged",
            "progress_percentage"
        ]
    ].describe()
)


print("\n--- Task Priority Distribution ---")

priority_columns = [
    "task_priority_Critical",
    "task_priority_High",
    "task_priority_Low",
    "task_priority_Medium",
    "task_priority_Unknown"
]

for col in priority_columns:
    print(col, ":", project_df[col].sum())


print("\n--- Task Status Distribution ---")

status_columns = [
    "task_status_Blocked",
    "task_status_Completed",
    "task_status_In Progress",
    "task_status_Not Started",
    "task_status_Unknown"
]

for col in status_columns:
    print(col, ":", project_df[col].sum())
# Out:
# --- Numerical Statistics ---
#        workload_percentage  active_tasks  estimated_hours  hours_logged  \
# count         50000.000000  50000.000000     50000.000000  50000.000000
# mean             55.609428      3.701600        36.647724     30.320410
# std              22.268091      1.884534        11.005495     13.036915
# min               0.000000      0.000000         2.000000      0.000000
# 25%              40.500000      2.000000        29.300000     21.400000
# 50%              55.700000      4.000000        36.400000     28.900000
# 75%              71.200000      5.000000        43.800000     37.500000
# max             100.000000     10.000000        91.500000    209.900000
#
#        progress_percentage
# count         50000.000000
# mean             78.773878
# std              19.438610
# min               0.000000
# 25%              66.000000
# 50%              82.000000
# 75%              97.725000
# max             100.000000
#
# --- Task Priority Distribution ---
# task_priority_Critical : 3385
# task_priority_High : 12137
# task_priority_Low : 9920
# task_priority_Medium : 23808
# task_priority_Unknown : 750
#
# --- Task Status Distribution ---
# task_status_Blocked : 2938
# task_status_Completed : 17136
# task_status_In Progress : 23312
# task_status_Not Started : 6014
# task_status_Unknown : 600

# %%
print("\n--- COMPLETE PRIORITY DISTRIBUTION ---")

for col in priority_columns:
    print(f"{col}: {project_df[col].sum()}")


print("\n--- COMPLETE STATUS DISTRIBUTION ---")

for col in status_columns:
    print(f"{col}: {project_df[col].sum()}")
# Out:
# --- COMPLETE PRIORITY DISTRIBUTION ---
# task_priority_Critical: 3385
# task_priority_High: 12137
# task_priority_Low: 9920
# task_priority_Medium: 23808
# task_priority_Unknown: 750
#
# --- COMPLETE STATUS DISTRIBUTION ---
# task_status_Blocked: 2938
# task_status_Completed: 17136
# task_status_In Progress: 23312
# task_status_Not Started: 6014
# task_status_Unknown: 600

# %%
# -----------------------------
# Step 4: Risk Indicators
# -----------------------------

project_df["effort_utilization"] = (
    project_df["hours_logged"] /
    project_df["estimated_hours"]
) * 100

project_df["effort_progress_gap"] = (
    project_df["effort_utilization"] -
    project_df["progress_percentage"]
)

print("\n--- Risk Indicators ---")

print(
    project_df[
        [
            "effort_utilization",
            "effort_progress_gap"
        ]
    ].describe()
)
# Out:
# --- Risk Indicators ---
#        effort_utilization  effort_progress_gap
# count        50000.000000         50000.000000
# mean            82.924285             4.150407
# std             25.782950            17.637596
# min              0.000000           -80.581560
# 25%             67.012359            -4.353086
# 50%             82.201171             2.770843
# 75%             97.345133            10.280314
# max           1445.000000          1387.700000

# %%
print("Effort utilization > 100%:",
      (project_df["effort_utilization"] > 100).sum())

print("Effort utilization > 120%:",
      (project_df["effort_utilization"] > 120).sum())

print("Effort utilization > 150%:",
      (project_df["effort_utilization"] > 150).sum())

print("Effort utilization > 200%:",
      (project_df["effort_utilization"] > 200).sum())
# Out:
# Effort utilization > 100%: 10608
# Effort utilization > 120%: 2645
# Effort utilization > 150%: 418
# Effort utilization > 200%: 169

# %%
# Cap effort utilization at 150%
project_df["effort_utilization_capped"] = (
    project_df["effort_utilization"].clip(upper=150)
)

# Convert to 0–100 risk contribution
project_df["effort_risk"] = (
    project_df["effort_utilization_capped"] / 150
) * 100

print(project_df[
    ["effort_utilization", "effort_utilization_capped", "effort_risk"]
].describe())
# Out:
#        effort_utilization  effort_utilization_capped   effort_risk
# count        50000.000000               50000.000000  50000.000000
# mean            82.924285                  82.472678     54.981786
# std             25.782950                  22.995124     15.330082
# min              0.000000                   0.000000      0.000000
# 25%             67.012359                  67.012359     44.674906
# 50%             82.201171                  82.201171     54.800781
# 75%             97.345133                  97.345133     64.896755
# max           1445.000000                 150.000000    100.000000

# %%
print("\n--- Workload Distribution ---")

print(project_df["workload_percentage"].describe())

print("\nWorkload thresholds:")

print("> 70% :", (project_df["workload_percentage"] > 70).sum())
print("> 80% :", (project_df["workload_percentage"] > 80).sum())
print("> 90% :", (project_df["workload_percentage"] > 90).sum())
print("> 95% :", (project_df["workload_percentage"] > 95).sum())
# Out:
# --- Workload Distribution ---
# count    50000.000000
# mean        55.609428
# std         22.268091
# min          0.000000
# 25%         40.500000
# 50%         55.700000
# 75%         71.200000
# max        100.000000
# Name: workload_percentage, dtype: float64
#
# Workload thresholds:
# > 70% : 13006
# > 80% : 7325
# > 90% : 3575
# > 95% : 2525

# %%
# -----------------------------
# Workload Risk
# -----------------------------

project_df["workload_risk"] = project_df["workload_percentage"]

print("\n--- Workload Risk ---")
print(project_df["workload_risk"].describe())
# Out:
# --- Workload Risk ---
# count    50000.000000
# mean        55.609428
# std         22.268091
# min          0.000000
# 25%         40.500000
# 50%         55.700000
# 75%         71.200000
# max        100.000000
# Name: workload_risk, dtype: float64

# %%
print("\n--- Active Tasks Distribution ---")

print(project_df["active_tasks"].describe())

print("\nActive task counts:")

print(project_df["active_tasks"].value_counts().sort_index())
# Out:
# --- Active Tasks Distribution ---
# count    50000.000000
# mean         3.701600
# std          1.884534
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          5.000000
# max         10.000000
# Name: active_tasks, dtype: float64
#
# Active task counts:
# active_tasks
# 0     2381
# 1     4022
# 2     6980
# 3     9789
# 4     9899
# 5     8226
# 6     5185
# 7     2482
# 8      824
# 9      191
# 10      21
# Name: count, dtype: int64

# %%
# -----------------------------
# Active Tasks Risk
# -----------------------------

project_df["active_tasks_risk"] = (
    project_df["active_tasks"] / 10
) * 100

print("\n--- Active Tasks Risk ---")
print(project_df["active_tasks_risk"].describe())
# Out:
# --- Active Tasks Risk ---
# count    50000.00000
# mean        37.01600
# std         18.84534
# min          0.00000
# 25%         20.00000
# 50%         40.00000
# 75%         50.00000
# max        100.00000
# Name: active_tasks_risk, dtype: float64

# %%
# -----------------------------
# Priority
# -----------------------------

def get_priority(row):
    if row["task_priority_Critical"]:
        return "Critical"
    elif row["task_priority_High"]:
        return "High"
    elif row["task_priority_Medium"]:
        return "Medium"
    elif row["task_priority_Low"]:
        return "Low"
    else:
        return "Unknown"


project_df["priority"] = project_df.apply(get_priority, axis=1)

print("\n--- Priority Distribution ---")
print(project_df["priority"].value_counts())
# Out:
# --- Priority Distribution ---
# priority
# Medium      23808
# High        12137
# Low          9920
# Critical     3385
# Unknown       750
# Name: count, dtype: int64

# %%
# -----------------------------
# Task Status
# -----------------------------

def get_status(row):
    if row["task_status_Blocked"]:
        return "Blocked"
    elif row["task_status_Completed"]:
        return "Completed"
    elif row["task_status_In Progress"]:
        return "In Progress"
    elif row["task_status_Not Started"]:
        return "Not Started"
    else:
        return "Unknown"


project_df["status"] = project_df.apply(get_status, axis=1)

print("\n--- Status Distribution ---")
print(project_df["status"].value_counts())
# Out:
# --- Status Distribution ---
# status
# In Progress    23312
# Completed      17136
# Not Started     6014
# Blocked         2938
# Unknown          600
# Name: count, dtype: int64

# %%
# -----------------------------
# Priority Risk
# -----------------------------

priority_risk_map = {
    "Critical": 100,
    "High": 75,
    "Medium": 50,
    "Low": 25,
    "Unknown": 0
}

project_df["priority_risk"] = project_df["priority"].map(priority_risk_map)


# -----------------------------
# Status Risk
# -----------------------------

status_risk_map = {
    "Blocked": 100,
    "In Progress": 50,
    "Not Started": 40,
    "Completed": 0,
    "Unknown": 0
}

project_df["status_risk"] = project_df["status"].map(status_risk_map)


print("\n--- Priority Risk ---")
print(project_df["priority_risk"].describe())

print("\n--- Status Risk ---")
print(project_df["status_risk"].describe())
# Out:
# --- Priority Risk ---
# count    50000.000000
# mean        53.743500
# std         21.643892
# min          0.000000
# 25%         50.000000
# 50%         50.000000
# 75%         75.000000
# max        100.000000
# Name: priority_risk, dtype: float64
#
# --- Status Risk ---
# count    50000.000000
# mean        33.999200
# std         28.101925
# min          0.000000
# 25%          0.000000
# 50%         50.000000
# 75%         50.000000
# max        100.000000
# Name: status_risk, dtype: float64

# %%
# -----------------------------
# Progress Risk
# -----------------------------

# Positive gap means effort consumed is higher than progress
project_df["progress_risk"] = (
    project_df["effort_progress_gap"]
    .clip(lower=0, upper=50)
    / 50
) * 100

print("\n--- Progress Risk ---")
print(project_df["progress_risk"].describe())
# Out:
# --- Progress Risk ---
# count    50000.000000
# mean        13.334618
# std         18.911115
# min          0.000000
# 25%          0.000000
# 50%          5.541685
# 75%         20.560628
# max        100.000000
# Name: progress_risk, dtype: float64

# %%
# -----------------------------
# Final Risk Score
# -----------------------------

project_df["risk_score"] = (
    0.25 * project_df["effort_risk"] +
    0.25 * project_df["progress_risk"] +
    0.20 * project_df["workload_risk"] +
    0.15 * project_df["priority_risk"] +
    0.10 * project_df["status_risk"] +
    0.05 * project_df["active_tasks_risk"]
)

print("\n--- Risk Score ---")
print(project_df["risk_score"].describe())
# Out:
# --- Risk Score ---
# count    50000.000000
# mean        41.513231
# std         10.101400
# min          9.263956
# 25%         34.737040
# 50%         40.609876
# 75%         47.077396
# max         94.790000
# Name: risk_score, dtype: float64

# %%
print("\n--- Risk Score Thresholds ---")

print("> 30:", (project_df["risk_score"] > 30).sum())
print("> 40:", (project_df["risk_score"] > 40).sum())
print("> 50:", (project_df["risk_score"] > 50).sum())
print("> 60:", (project_df["risk_score"] > 60).sum())
print("> 70:", (project_df["risk_score"] > 70).sum())
print("> 80:", (project_df["risk_score"] > 80).sum())
# Out:
# --- Risk Score Thresholds ---
# > 30: 44665
# > 40: 26357
# > 50: 8634
# > 60: 2332
# > 70: 731
# > 80: 143

# %%
def get_risk_level(score):
    if score <= 30:
        return "Low"
    elif score <= 50:
        return "Medium"
    elif score <= 70:
        return "High"
    else:
        return "Critical"


project_df["risk_level"] = project_df["risk_score"].apply(get_risk_level)

print("\n--- Risk Level Distribution ---")
print(project_df["risk_level"].value_counts())
# Out:
# --- Risk Level Distribution ---
# risk_level
# Medium      36031
# High         7903
# Low          5335
# Critical      731
# Name: count, dtype: int64

# %%
print("\n--- Example Risk Results ---")

columns_to_show = [
    "employee_id",
    "priority",
    "status",
    "workload_percentage",
    "active_tasks",
    "estimated_hours",
    "hours_logged",
    "progress_percentage",
    "effort_utilization",
    "risk_score",
    "risk_level"
]

print(
    project_df[columns_to_show]
    .sort_values("risk_score", ascending=False)
    .head(10)
)
# Out:
# --- Example Risk Results ---
#       employee_id  priority       status  workload_percentage  active_tasks  \
# 10561     EMP4277      High      Blocked                 97.7             8
# 37277     EMP1618  Critical  In Progress                100.0             6
# 43409     EMP4336  Critical      Blocked                 70.7             6
# 6467      EMP2859  Critical  In Progress                 93.0             7
# 24775     EMP2724      High      Blocked                 85.8             6
# 16058      EMP999    Medium      Blocked                 96.8             8
# 8768      EMP4963  Critical      Blocked                 68.1             4
# 40873     EMP1792  Critical  Not Started                 89.4             7
# 24231     EMP1757    Medium      Blocked                100.0             5
# 6340       EMP522      High  In Progress                100.0             7
#
#        estimated_hours  hours_logged  progress_percentage  effort_utilization  \
# 10561             19.2          28.9                 65.1          150.520833
# 37277             65.4         140.6                 71.5          214.984709
# 43409             54.9          91.3                 67.9          166.302368
# 6467              36.4          68.8                100.0          189.010989
# 24775             56.8         113.2                 58.8          199.295775
# 16058             43.6          70.0                100.0          160.550459
# 8768              56.8          89.8                 59.4          158.098592
# 40873             56.5         209.9                100.0          371.504425
# 24231             47.6         135.5                 82.4          284.663866
# 6340              35.7          53.4                 54.3          149.579832
#
#        risk_score risk_level
# 10561   94.790000   Critical
# 37277   93.000000   Critical
# 43409   92.140000   Critical
# 6467    92.100000   Critical
# 24775   91.410000   Critical
# 16058   90.860000   Critical
# 8768    90.620000   Critical
# 40873   90.380000   Critical
# 24231   90.000000   Critical
# 6340    89.679972   Critical

# %%
print("\n--- Sample From Each Risk Level ---")

for level in ["Low", "Medium", "High", "Critical"]:
    print(f"\n{level}:")
    print(
        project_df[project_df["risk_level"] == level][
            columns_to_show
        ].head(3)
    )
# Out:
# --- Sample From Each Risk Level ---
#
# Low:
#    employee_id priority       status  workload_percentage  active_tasks  \
# 10     EMP2839  Unknown    Completed                 39.9             2
# 14      EMP916   Medium    Completed                 42.5             5
# 17     EMP4536      Low  Not Started                 33.6             3
#
#     estimated_hours  hours_logged  progress_percentage  effort_utilization  \
# 10             34.1          20.8                 48.7           60.997067
# 14             30.4          20.5                 74.5           67.434211
# 17             43.4          20.6                 55.5           47.465438
#
#     risk_score risk_level
# 10   25.294712        Low
# 14   29.739035        Low
# 17   23.880906        Low
#
# Medium:
#   employee_id priority       status  workload_percentage  active_tasks  \
# 0     EMP2373     High  In Progress                 27.0             2
# 1     EMP4021   Medium  In Progress                100.0             8
# 2     EMP2457   Medium  In Progress                 67.9             2
#
#    estimated_hours  hours_logged  progress_percentage  effort_utilization  \
# 0             36.5          25.1                 76.8           68.767123
# 1             44.4          21.9                 56.9           49.324324
# 2             32.0          21.2                 56.6           66.250000
#
#    risk_score risk_level
# 0   34.111187     Medium
# 1   44.720721     Medium
# 2   42.946667     Medium
#
# High:
#    employee_id priority       status  workload_percentage  active_tasks  \
# 12      EMP615     High  In Progress                 14.0             0
# 13      EMP532      Low  In Progress                 95.8             8
# 21     EMP4271     High    Completed                100.0             1
#
#     estimated_hours  hours_logged  progress_percentage  effort_utilization  \
# 12             24.3          30.0                100.0          123.456790
# 13             19.9          18.2                 78.5           91.457286
# 21             33.7          32.5                 88.1           96.439169
#
#     risk_score risk_level
# 12   51.354527       High
# 13   53.631524       High
# 21   51.992779       High
#
# Critical:
#    employee_id  priority       status  workload_percentage  active_tasks  \
# 39     EMP2002  Critical  In Progress                 93.6             5
# 56     EMP1547  Critical  In Progress                 54.3             3
# 98     EMP2532       Low      Blocked                 65.4             5
#
#     estimated_hours  hours_logged  progress_percentage  effort_utilization  \
# 39             54.8          66.8                100.0          121.897810
# 56             49.5          76.2                100.0          153.939394
# 98             39.1          64.2                100.0          164.194373
#
#     risk_score risk_level
# 39   72.485207   Critical
# 56   82.360000   Critical
# 98   79.330000   Critical

# %%
for level in ["Low", "Medium", "High", "Critical"]:
    sample = project_df[
        project_df["risk_level"] == level
    ][[
        "priority",
        "status",
        "workload_percentage",
        "active_tasks",
        "effort_utilization",
        "progress_percentage",
        "risk_score",
        "risk_level"
    ]].head(3)

    print(f"\n========== {level.upper()} ==========")
    print(sample.to_string(index=False))
# Out:
# ========== LOW ==========
# priority      status  workload_percentage  active_tasks  effort_utilization  progress_percentage  risk_score risk_level
#  Unknown   Completed                 39.9             2           60.997067                 48.7   25.294712        Low
#   Medium   Completed                 42.5             5           67.434211                 74.5   29.739035        Low
#      Low Not Started                 33.6             3           47.465438                 55.5   23.880906        Low
#
# ========== MEDIUM ==========
# priority      status  workload_percentage  active_tasks  effort_utilization  progress_percentage  risk_score risk_level
#     High In Progress                 27.0             2           68.767123                 76.8   34.111187     Medium
#   Medium In Progress                100.0             8           49.324324                 56.9   44.720721     Medium
#   Medium In Progress                 67.9             2           66.250000                 56.6   42.946667     Medium
#
# ========== HIGH ==========
# priority      status  workload_percentage  active_tasks  effort_utilization  progress_percentage  risk_score risk_level
#     High In Progress                 14.0             0          123.456790                100.0   51.354527       High
#      Low In Progress                 95.8             8           91.457286                 78.5   53.631524       High
#     High   Completed                100.0             1           96.439169                 88.1   51.992779       High
#
# ========== CRITICAL ==========
# priority      status  workload_percentage  active_tasks  effort_utilization  progress_percentage  risk_score risk_level
# Critical In Progress                 93.6             5          121.897810                100.0   72.485207   Critical
# Critical In Progress                 54.3             3          153.939394                100.0   82.360000   Critical
#      Low     Blocked                 65.4             5          164.194373                100.0   79.330000   Critical

# %%
import pandas as pd


# ============================================================
# 1. LOAD DATA
# ============================================================

DATA_PATH = "C:/Users/nived/New folder (2)/AI-Business-Operations-Management-Platform/datasets/cleaned/Business_Operation_ml_ready.csv"

df = pd.read_csv(DATA_PATH)


# ============================================================
# 2. SELECT PROJECT MANAGEMENT FEATURES
# ============================================================

project_features = [
    "employee_id",
    "workload_percentage",
    "active_tasks",
    "estimated_hours",
    "hours_logged",
    "progress_percentage",
    "task_priority_Critical",
    "task_priority_High",
    "task_priority_Low",
    "task_priority_Medium",
    "task_priority_Unknown",
    "task_status_Blocked",
    "task_status_Completed",
    "task_status_In Progress",
    "task_status_Not Started",
    "task_status_Unknown"
]

project_df = df[project_features].copy()


# ============================================================
# 3. CONVERT PRIORITY
# ============================================================

def get_priority(row):

    if row["task_priority_Critical"]:
        return "Critical"

    elif row["task_priority_High"]:
        return "High"

    elif row["task_priority_Medium"]:
        return "Medium"

    elif row["task_priority_Low"]:
        return "Low"

    else:
        return "Unknown"


project_df["priority"] = project_df.apply(get_priority, axis=1)


# ============================================================
# 4. CONVERT STATUS
# ============================================================

def get_status(row):

    if row["task_status_Blocked"]:
        return "Blocked"

    elif row["task_status_Completed"]:
        return "Completed"

    elif row["task_status_In Progress"]:
        return "In Progress"

    elif row["task_status_Not Started"]:
        return "Not Started"

    else:
        return "Unknown"


project_df["status"] = project_df.apply(get_status, axis=1)


# ============================================================
# 5. EFFORT UTILIZATION
# ============================================================

project_df["effort_utilization"] = (
    project_df["hours_logged"] /
    project_df["estimated_hours"]
) * 100


# ============================================================
# 6. EFFORT RISK
# ============================================================

project_df["effort_utilization_capped"] = (
    project_df["effort_utilization"].clip(upper=150)
)

project_df["effort_risk"] = (
    project_df["effort_utilization_capped"] / 150
) * 100


# ============================================================
# 7. WORKLOAD RISK
# ============================================================

project_df["workload_risk"] = (
    project_df["workload_percentage"]
)


# ============================================================
# 8. ACTIVE TASK RISK
# ============================================================

project_df["active_tasks_risk"] = (
    project_df["active_tasks"] / 10
) * 100


# ============================================================
# 9. PRIORITY RISK
# ============================================================

priority_risk_map = {
    "Critical": 100,
    "High": 75,
    "Medium": 50,
    "Low": 25,
    "Unknown": 0
}

project_df["priority_risk"] = (
    project_df["priority"].map(priority_risk_map)
)


# ============================================================
# 10. STATUS RISK
# ============================================================

status_risk_map = {
    "Blocked": 100,
    "In Progress": 50,
    "Not Started": 40,
    "Completed": 0,
    "Unknown": 0
}

project_df["status_risk"] = (
    project_df["status"].map(status_risk_map)
)


# ============================================================
# 11. PROGRESS RISK
# ============================================================

project_df["effort_progress_gap"] = (
    project_df["effort_utilization"] -
    project_df["progress_percentage"]
)

project_df["progress_risk"] = (
    project_df["effort_progress_gap"]
    .clip(lower=0, upper=50)
    / 50
) * 100


# ============================================================
# 12. FINAL RISK SCORE
# ============================================================

project_df["risk_score"] = (
    0.25 * project_df["effort_risk"] +
    0.25 * project_df["progress_risk"] +
    0.20 * project_df["workload_risk"] +
    0.15 * project_df["priority_risk"] +
    0.10 * project_df["status_risk"] +
    0.05 * project_df["active_tasks_risk"]
)


# ============================================================
# 13. RISK LEVEL
# ============================================================

def get_risk_level(score):

    if score <= 30:
        return "Low"

    elif score <= 50:
        return "Medium"

    elif score <= 70:
        return "High"

    else:
        return "Critical"


project_df["risk_level"] = (
    project_df["risk_score"].apply(get_risk_level)
)


# ============================================================
# 14. IDENTIFY RISK FACTORS
# ============================================================

def get_risk_factors(row):

    factors = []

    if row["effort_risk"] >= 70:
        factors.append("High effort utilization")

    if row["progress_risk"] >= 50:
        factors.append("Effort is high compared with progress")

    if row["workload_risk"] >= 80:
        factors.append("High workload")

    if row["active_tasks_risk"] >= 70:
        factors.append("High number of active tasks")

    if row["priority"] == "Critical":
        factors.append("Critical priority")

    elif row["priority"] == "High":
        factors.append("High priority")

    if row["status"] == "Blocked":
        factors.append("Task is blocked")

    return factors


project_df["risk_factors"] = (
    project_df.apply(get_risk_factors, axis=1)
)


# ============================================================
# 15. ANALYZE ONE TASK
# ============================================================

def analyze_task(index):

    row = project_df.loc[index]

    result = {
        "employee_id": row["employee_id"],
        "priority": row["priority"],
        "status": row["status"],
        "progress": round(row["progress_percentage"], 2),
        "workload": round(row["workload_percentage"], 2),
        "effort_utilization": round(
            row["effort_utilization"], 2
        ),
        "risk_score": round(
            row["risk_score"], 2
        ),
        "risk_level": row["risk_level"],
        "risk_factors": row["risk_factors"]
    }

    return result


# ============================================================
# 16. TEST
# ============================================================

result = analyze_task(10561)

print("\n========== PROJECT MANAGEMENT RISK ANALYSIS ==========")

for key, value in result.items():
    print(f"{key}: {value}")
# Out:
# ========== PROJECT MANAGEMENT RISK ANALYSIS ==========
# employee_id: EMP4277
# priority: High
# status: Blocked
# progress: 65.1
# workload: 97.7
# effort_utilization: 150.52
# risk_score: 94.79
# risk_level: Critical
# risk_factors: ['High effort utilization', 'Effort is high compared with progress', 'High workload', 'High number of active tasks', 'High priority', 'Task is blocked']
